# %%
from viewLatex import viewLatex
from relations import Relation, Relations

# %% [markdown]
# # Integer Relations
#
# You can create the set of all integer relations of a given size, depending on some properties.

# %%
list(Relations(2))
# Out:
# [The relation of size 2 given by relations (),
#  The relation of size 2 given by relations ((1, 2),),
#  The relation of size 2 given by relations ((2, 1),),
#  The relation of size 2 given by relations ((1, 2), (2, 1))]

# %%
list(Relations(2, anti_symmetric = True))
# Out:
# [The relation of size 2 given by relations (),
#  The relation of size 2 given by relations ((1, 2),),
#  The relation of size 2 given by relations ((2, 1),)]

# %%
list(Relations(3, anti_symmetric = True, transitive = True))
# Out:
# [The relation of size 3 given by relations (),
#  The relation of size 3 given by relations ((2, 3),),
#  The relation of size 3 given by relations ((3, 2),),
#  The relation of size 3 given by relations ((1, 3),),
#  The relation of size 3 given by relations ((1, 3), (2, 3)),
#  The relation of size 3 given by relations ((3, 1),),
#  The relation of size 3 given by relations ((3, 2), (3, 1)),
#  The relation of size 3 given by relations ((1, 2),),
#  The relation of size 3 given by relations ((1, 2), (3, 2)),
#  The relation of size 3 given by relations ((1, 2), (1, 3)),
#  The relation of size 3 given by relations ((1, 2), (1, 3), (2, 3)),
#  The relation of size 3 given by relations ((1, 2), (1, 3), (3, 2)),
#  The relation of size 3 given by relations ((1, 2), (3, 2), (3, 1)),
#  The relation of size 3 given by relations ((2, 1),),
#  The relation of size 3 given by relations ((2, 3), (2, 1)),
#  The relation of size 3 given by relations ((1, 3), (2, 3), (2, 1)),
#  The relation of size 3 given by relations ((3, 1), (2, 1)),
#  The relation of size 3 given by relations ((2, 3), (3, 1), (2, 1)),
#  The relation of size 3 given by relations ((3, 2), (3, 1), (2, 1))]

# %% [markdown]
# You can also create a single relation and check its properties.

# %%
r = Relation(4, [(1,2),(2,4), (1,4),(4,3)])
viewLatex(r)

# %%
r.is_anti_symmetric()
# Out:
# True

# %%
r.is_transitive()
# Out:
# False

# %%
r.is_semi_transitive()
# Out:
# True

# %% [markdown]
# You can get the weak order poset and check its properties.

# %%
P2 = Relations(2).get_poset()

# %%
viewLatex(P2)

# %%
P3 = Relations(3).get_poset()

# %%
P3.is_lattice()
# Out:
# True

# %%
AS = Relations(3, anti_symmetric= True)
AS.isSubLattice()
# Out:
# True

# %%
R = Relations(3, anti_symmetric = True, transitive = True)
P = R.get_poset()

# %%
P.is_lattice()
# Out:
# True

# %%
viewLatex(P)

# %%
R.cardinality()
# Out:
# 19

# %%
R.isSubLattice()
# Out:
# The relation of size 3 given by relations ((2, 3),) The relation of size 3 given by relations ((1, 2),)
# False

# %% [markdown]
# As this point, Sage confirmed that the poset of antisymmetric and transitive relations is a lattice but not a sublattive of the lattice of integer relations.
#
# You can also compute the meet and join of 2 relations as well as the transitive decreasing deletions.

# %%
r1 = Relation(4, [(4,3),(3,2),(4,2),(4,1),(3,1),(1,2)])
viewLatex(r1)

# %%
r2 = Relation(4, [(4,1),(3,1),(2,1),(4,3),(2,3)])
viewLatex(r2)

# %%
r1.is_transitive()
# Out:
# True

# %%
r2.is_transitive()
# Out:
# True

# %%
r3 = Relations().meet(r1,r2)
viewLatex(r3)

# %%
r3.is_transitive()
# Out:
# False

# %%
r4 = r3.semiTransitiveClosure().transDelDec()
viewLatex(r4)

# %%
L = LatticePoset(Relations(4, transitive = True, anti_symmetric = True).get_poset())

# %%
L.meet(r1,r2) == r4
# Out:
# True

# %%
# checks that the semi transitive closure + trans del dec indeed gives the meet in the poset lattice
all(L.meet(x,y) == Relations().meet(x,y).semiTransitiveClosure().transDelDec() for x in L for y in L)
# Out:
# True

# %% [markdown]
# ## Integer posets
#
# Even though Integer posets can be obtained through integer relations, we have a specific class to work on them.

# %%
from IntegerPosets import IntegerPosets, IntegerPoset

# %%
IP3 = IntegerPosets(3)
IP3
# Out:
# Integer posets of size 3

# %%
list(IP3)
# Out:
# [The integer poset of size 3 induced by relations (),
#  The integer poset of size 3 induced by relations ((2, 3),),
#  The integer poset of size 3 induced by relations ((3, 2),),
#  The integer poset of size 3 induced by relations ((1, 3),),
#  The integer poset of size 3 induced by relations ((1, 3), (2, 3)),
#  The integer poset of size 3 induced by relations ((3, 1),),
#  The integer poset of size 3 induced by relations ((3, 2), (3, 1)),
#  The integer poset of size 3 induced by relations ((1, 2),),
#  The integer poset of size 3 induced by relations ((1, 2), (3, 2)),
#  The integer poset of size 3 induced by relations ((1, 2), (1, 3)),
#  The integer poset of size 3 induced by relations ((1, 2), (2, 3)),
#  The integer poset of size 3 induced by relations ((1, 2), (1, 3), (3, 2)),
#  The integer poset of size 3 induced by relations ((1, 2), (3, 2), (3, 1)),
#  The integer poset of size 3 induced by relations ((2, 1),),
#  The integer poset of size 3 induced by relations ((2, 3), (2, 1)),
#  The integer poset of size 3 induced by relations ((1, 3), (2, 3), (2, 1)),
#  The integer poset of size 3 induced by relations ((2, 1), (3, 1)),
#  The integer poset of size 3 induced by relations ((2, 3), (2, 1), (3, 1)),
#  The integer poset of size 3 induced by relations ((2, 1), (3, 2))]

# %%
viewLatex(IP3.get_poset())

# %% [markdown]
# You can create a single integer poset and test its properties.

# %%
ip = IntegerPoset(3, [(1,3),(1,2),(3,2)])

# %%
viewLatex(ip)

# %%
ip.is_woip()
# Out:
# True

# %%
ip.is_woep()
# Out:
# True

# %%
ip.is_wof()
# Out:
# True

# %%
ip.is_toip()
# Out:
# False

# %% [markdown]
# You can also get a get a subset of posets by those properties and check the obtained lattice.

# %%
WOIP3 = IntegerPosets(3, woip = True)

# %%
viewLatex(WOIP3.get_poset())

# %%
WOIP3.isSubLattice()
# Out:
# The integer poset of size 3 induced by relations ((3, 2), (3, 1)) The integer poset of size 3 induced by relations ((2, 1), (3, 1))
# False

# %%
WOIP3.get_poset().is_lattice()
# Out:
# True

# %%
WOEP3 = IntegerPosets(3, woep = True)

# %%
viewLatex(WOEP3.get_poset())

# %%
WOEP3.isSubLattice()
# Out:
# True

# %%
WOF3 = IntegerPosets(3, wof = True)

# %%
viewLatex(WOF3.get_poset())

# %%
WOF3.isSubLattice()
# Out:
# The integer poset of size 3 induced by relations () The integer poset of size 3 induced by relations ((1, 2), (3, 2))
# False

# %%
WOF3.get_poset().is_lattice()
# Out:
# True

# %%
TOIP3 = IntegerPosets(3, toip = True)

# %%
viewLatex(TOIP3.get_poset())

# %%
TOIP3.isSubLattice()
# Out:
# True

# %%
TOF3 = IntegerPosets(3, tof = True)

# %%
viewLatex(TOF3.get_poset())

# %%
TOF3.isSubLattice()
# Out:
# The integer poset of size 3 induced by relations () The integer poset of size 3 induced by relations ((2, 3), (2, 1))
# False

# %%
TOF3.get_poset().is_lattice()
# Out:
# True

# %%
PIP3 = IntegerPosets(3, pip = (-1, -1, -1))

# %%
viewLatex(PIP3.get_poset())

# %%
PEP4 = IntegerPosets(4, pep = (0,-1,0,-1))

# %%
viewLatex(PEP4.get_poset())
